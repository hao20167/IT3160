# %% [markdown]
# # Low Level Agent Training - Beta -90
#
# This notebook trains the low-level agent with beta=-90.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Change directory to the project root
import os
# EDIT THIS PATH TO MATCH YOUR DRIVE LOCATION
project_path = '/content/drive/MyDrive/PROJ/HydraHFT2/main'
os.chdir(project_path)
print(f"Current working directory: {os.getcwd()}")

# %%
# !pip install tensorboard

# %%
# Training Configuration
BETA = -90
DATASET = "BTCUSDT"
TRAIN_PATH = f"data/{DATASET}/final/train"
LOG_DIR = f"log/train/{DATASET}/low_level/beta_{BETA}"

# Ensure log directory exists
# !mkdir -p {LOG_DIR}

print(f"Starting training for Beta={BETA}...")

# Run the training script
# !python model/low_level/ddqn_pes_risk_aware.py \
    --beta {BETA} \
    --train_data_path {TRAIN_PATH} \
    --dataset_name {DATASET} \
    --batch_size 2048
